# %% [markdown]
# # パラメータ・チューニング（グリッドサーチ）

# %% [markdown]
# ここではグリッドサーチの実装方法について学びます。<br>
# まずは分類用のサンプルデータを読み込みます。

# %%
# Breast cancer dataset for binary classification
import pandas as pd
from sklearn.datasets import load_breast_cancer

# Set X and y
dataset = load_breast_cancer()
X = pd.DataFrame(dataset.data, columns=dataset.feature_names)
y = pd.DataFrame(dataset.target, columns=['y'])
X.join(y).head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871 ...          17.33           184.60      2019.0
# 1                 0.05667 ...          23.41           158.80      1956.0
# 2                 0.05999 ...          25.53           152.50      1709.0
# 3                 0.09744 ...          26.50            98.87       567.7
# 4                 0.05883 ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  y
# 0          0.4601                  0.11890  0
# 1          0.2750                  0.08902  0
# 2          0.3613                  0.08758  0
# 3          0.6638                  0.17300  0
# 4          0.2364                  0.07678  0
#
# [5 rows x 31 columns]

# %% [markdown]
# 分類器としてロジスティック回帰と勾配ブースティングを設定しておきます。<br><b>推定器の略称として"est"、次元圧縮に"pca"を使っていますが、本記号がグリッドサーチ時の設定にも使われます</b>。

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score

# パイプラインの設定
pipe_logistic = Pipeline([('scl',StandardScaler()),
                          ('pca', PCA(random_state=1)),
                          ('est',LogisticRegression(random_state=1))])

# %% [markdown]
# グリッドサーチによる探索条件の設定は、<br><b>上記で指定した"pca"や"est"に紐付と各アルゴリズムの持つパラメータ名を結合させて指定します。</b><br>下記例の設定内容は以下の通り計24通りです。
# - 主成分圧縮
#  - 抽出主成分数を5,7,9の3通り
# - ロジスティック回帰
#  - 正則化パラメータは0.1から100の4通り、正則化はL1とL2の2通り

# %%
# パラメータグリッドの設定
param_grid_logistic = {'pca__n_components':[5,7,9],
                       'est__C':[0.1,1.0,10.0,100.0],
                       'est__penalty':['l1','l2']}

# %% [markdown]
# 設定は以上です。ハイパーパラメータの異なるモデルの構築と評価はGridSerachCVで行うことができます。<br>gsをfitした時点で、各パラメータのモデルの構築と評価を終えています。

# %%
print('探索空間:%s' %param_grid_logistic)
gs = GridSearchCV(estimator=pipe_logistic,
                  param_grid=param_grid_logistic,
                  scoring='f1',
                  cv=3,
                  return_train_score=False)
gs = gs.fit(X, y.as_matrix().ravel())

# 探索した結果のベストスコアとパラメータの取得
print('Best Score:', gs.best_score_)
print('Best Params', gs.best_params_)
# Out:
# 探索空間:{'pca__n_components': [5, 7, 9], 'est__C': [0.1, 1.0, 10.0, 100.0], 'est__penalty': ['l1', 'l2']}
# C:\Users\hiroa\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   import sys
# Best Score: 0.9833314910965807
# Best Params {'est__C': 0.1, 'est__penalty': 'l2', 'pca__n_components': 9}

# %% [markdown]
# ベストモデルで予測をしたい場合は以下です。

# %%
gs.predict_proba(X)
# Out:
# array([[9.99990949e-01, 9.05116719e-06],
#        [9.95490682e-01, 4.50931764e-03],
#        [9.99899156e-01, 1.00844229e-04],
#        ...,
#        [9.51518892e-01, 4.84811076e-02],
#        [9.99999833e-01, 1.66748227e-07],
#        [4.85054239e-04, 9.99514946e-01]])

# %% [markdown]
# グリッドサーチの探索結果を閲覧したい場合は以下です。

# %%
pd.DataFrame(gs.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_est__C  \
# 0        0.000000      0.000000         0.000000        0.000000          0.1
# 1        0.000000      0.000000         0.005209        0.007366          0.1
# 2        0.005207      0.007363         0.000000        0.000000          0.1
# 3        0.000000      0.000000         0.000000        0.000000          0.1
# 4        0.000000      0.000000         0.005207        0.007363          0.1
# 5        0.000000      0.000000         0.005208        0.007365          0.1
# 6        0.005207      0.007364         0.000000        0.000000            1
# 7        0.005216      0.007377         0.000000        0.000000            1
# 8        0.000000      0.000000         0.000000        0.000000            1
# 9        0.005207      0.007363         0.000000        0.000000            1
# 10       0.001334      0.001887         0.000000        0.000000            1
# 11       0.005218      0.007380         0.000000        0.000000            1
# 12       0.005197      0.007349         0.000000        0.000000           10
# 13       0.000000      0.000000         0.005207        0.007364           10
# 14       0.005218      0.007379         0.005207        0.007364           10
# 15       0.005197      0.007349         0.000000        0.000000           10
# 16       0.000000      0.000000         0.000000        0.000000           10
# 17       0.005210      0.007369         0.000000        0.000000           10
# 18       0.000000      0.000000         0.000000        0.000000          100
# 19       0.000000      0.000000         0.000000        0.000000          100
# 20       0.005211      0.007370         0.000000        0.000000          100
# 21       0.005203      0.007358         0.000000        0.000000          100
# 22       0.005207      0.007364         0.000000        0.000000          100
# 23       0.005207      0.007364         0.000000        0.000000          100
#
#    param_est__penalty param_pca__n_components  \
# 0                  l1                       5
# 1                  l1                       7
# 2                  l1                       9
# 3                  l2                       5
# 4                  l2                       7
# 5                  l2                       9
# 6                  l1                       5
# 7                  l1                       7
# 8                  l1                       9
# 9                  l2                       5
# 10                 l2                       7
# 11                 l2                       9
# 12                 l1                       5
# 13                 l1                       7
# 14                 l1                       9
# 15                 l2                       5
# 16                 l2                       7
# 17                 l2                       9
# 18                 l1                       5
# 19                 l1                       7
# 20                 l1                       9
# 21                 l2                       5
# 22                 l2                       7
# 23                 l2                       9
#
#                                                params  split0_test_score  \
# 0   {'est__C': 0.1, 'est__penalty': 'l1', 'pca__n_...           0.966387
# 1   {'est__C': 0.1, 'est__penalty': 'l1', 'pca__n_...           0.966387
# 2   {'est__C': 0.1, 'est__penalty': 'l1', 'pca__n_...           0.966387
# 3   {'est__C': 0.1, 'est__penalty': 'l2', 'pca__n_...           0.979253
# 4   {'est__C': 0.1, 'est__penalty': 'l2', 'pca__n_...           0.975000
# 5   {'est__C': 0.1, 'est__penalty': 'l2', 'pca__n_...           0.983471
# 6   {'est__C': 1.0, 'est__penalty': 'l1', 'pca__n_...           0.974790
# 7   {'est__C': 1.0, 'est__penalty': 'l1', 'pca__n_...           0.974790
# 8   {'est__C': 1.0, 'est__penalty': 'l1', 'pca__n_...           0.970464
# 9   {'est__C': 1.0, 'est__penalty': 'l2', 'pca__n_...           0.983333
# 10  {'est__C': 1.0, 'est__penalty': 'l2', 'pca__n_...           0.979079
# 11  {'est__C': 1.0, 'est__penalty': 'l2', 'pca__n_...           0.991667
# 12  {'est__C': 10.0, 'est__penalty': 'l1', 'pca__n...           0.979079
# 13  {'est__C': 10.0, 'est__penalty': 'l1', 'pca__n...           0.983193
# 14  {'est__C': 10.0, 'est__penalty': 'l1', 'pca__n...           0.978903
# 15  {'est__C': 10.0, 'est__penalty': 'l2', 'pca__n...           0.979079
# 16  {'est__C': 10.0, 'est__penalty': 'l2', 'pca__n...           0.983193
# 17  {'est__C': 10.0, 'est__penalty': 'l2', 'pca__n...           0.978903
# 18  {'est__C': 100.0, 'est__penalty': 'l1', 'pca__...           0.979079
# 19  {'est__C': 100.0, 'est__penalty': 'l1', 'pca__...           0.983193
# 20  {'est__C': 100.0, 'est__penalty': 'l1', 'pca__...           0.978903
# 21  {'est__C': 100.0, 'est__penalty': 'l2', 'pca__...           0.979079
# 22  {'est__C': 100.0, 'est__penalty': 'l2', 'pca__...           0.983193
# 23  {'est__C': 100.0, 'est__penalty': 'l2', 'pca__...           0.978903
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.979424           0.983051         0.976275        0.007156
# 1            0.979424           0.983051         0.976275        0.007156
# 2            0.979424           0.983051         0.976275        0.007156
# 3            0.979424           0.978723         0.979134        0.000298
# 4            0.979424           0.974359         0.976264        0.002252
# 5            0.983471           0.983051         0.983331        0.000198
# 6            0.979253           0.974359         0.976137        0.002213
# 7            0.971193           0.974359         0.973446        0.001604
# 8            0.975410           0.978723         0.974859        0.003393
# 9            0.983471           0.974359         0.980398        0.004260
# 10           0.971193           0.965517         0.971941        0.005560
# 11           0.975410           0.978723         0.981939        0.007019
# 12           0.975000           0.974359         0.976149        0.002091
# 13           0.967213           0.965517         0.971986        0.007965
# 14           0.979424           0.965517         0.974631        0.006431
# 15           0.975000           0.974359         0.976149        0.002091
# 16           0.967213           0.965517         0.971986        0.007965
# 17           0.979424           0.965517         0.974631        0.006431
# 18           0.975000           0.974359         0.976149        0.002091
# 19           0.967213           0.961039         0.970498        0.009335
# 20           0.979424           0.965517         0.974631        0.006431
# 21           0.975000           0.974359         0.976149        0.002091
# 22           0.967213           0.961039         0.970498        0.009335
# 23           0.979424           0.965517         0.974631        0.006431
#
#     rank_test_score
# 0                 5
# 1                 5
# 2                 5
# 3                 4
# 4                 8
# 5                 1
# 6                13
# 7                19
# 8                14
# 9                 3
# 10               22
# 11                2
# 12                9
# 13               20
# 14               15
# 15                9
# 16               20
# 17               15
# 18                9
# 19               23
# 20               15
# 21                9
# 22               23
# 23               15

# %% [markdown]
# 以上でグリッドサーチの実装方法は終了です。
